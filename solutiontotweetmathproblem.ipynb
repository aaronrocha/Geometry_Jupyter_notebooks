# %%
from sympy import *

# %%
init_printing()

# %%
x = symbols('x')

# %%
expr = x**4 - 12*x**2 + 16*sqrt(2)*x;expr
# Out:
#  4       2
# x  - 12⋅x  + 16⋅√2⋅x

# %%
plot(expr, (x, -7, 7))

# %%
N(solveset(Eq(expr, 0)))
# Out:
# {-4.17387177455567, 0, 2.08693588727783 - 1.03242636193792⋅ⅈ, 2.08693588727783
#  + 1.03242636193792⋅ⅈ}

# %%
for root in _:
    print(root)
# Out:
# -4.17387177455567
# 0
# 2.08693588727783 - 1.03242636193792*I
# 2.08693588727783 + 1.03242636193792*I
