# %% [markdown]
# ## Straight Lines

# %% [markdown]
# ### example 1
#
# Determine the equations of the following lines;
#
# #### a) The line passing through the point(3,4) and a gradient of -2

# %%
from sympy import *

# %%
init_printing()

# %%
A = Point(3, -4)
m = -2

# %%
Line_a = Line(A, slope=m);Line_a
# Out:
# Line2D(Point2D(3, -4), Point2D(4, -6))

# %%
Line_a.equation()
# Out:
# 2⋅x + y - 2

# %%
Line_a.slope
# Out:
# -2

# %%
x = symbols('x')

# %%
plot(-2*x + 2)

# %% [markdown]
# ### b) The line passing through F(-4, 2) and G(-1, 2)

# %%
F, G = Point(-4, 2), Point(-1, 2)

# %%
line_b = Line(F, G)

# %%
line_b.equation()
# Out:
# y - 2

# %%
line_b.slope
# Out:
# 0

# %%
y = symbols('y')
plot(2, (x, -3, 3))

# %%
F
# Out:
# Point2D(-4, 2)

# %%
G
# Out:
# Point2D(-1, 2)

# %%
(G.y - F.y) / (G.x - F.x)
# Out:
# 0

# %% [markdown]
# ### c) The line parallel to 3y - 2x = 6 and going through (9, -1).

# %%
line_c = Rational(2, 3)* x + 2;line_c
# Out:
# 2⋅x
# ─── + 2
#  3

# %% [markdown]
# the slope of line c is 2/3, so our parallel line will have a slpe of 2/3.  We plug into our point slope form to get the equation of parallel line.
#
# y - (-1) = 2/3 * (x - 9)
#
# y = 2/3x - 2/3 * 9 - 1

# %%
Eq(Rational(2,3)* x- Rational(2,3)*9 - 1, 0)
# Out:
# 2⋅x
# ─── - 7 = 0
#  3

# %%
line_c_parallel = Rational(2,3) * x - 7

# %%
plot(line_c, line_c_parallel)

# %%
line_c1 = Line(Point(0, 2), slope=Rational(2,3))
line_cp = Line(Point(9, -1), slope=Rational(2,3))

# %%
line_c1.is_parallel(line_cp)
# Out:
# True

# %%
line_c1.equation()
# Out:
#   2⋅x
# - ─── + y - 2
#    3

# %%
line_cp.equation()
# Out:
#   2⋅x
# - ─── + y + 7
#    3

# %% [markdown]
# ### d) The line perpendicular to y = 1/2 x + 1 and passing (-6, 2).

# %%
line_d = Line(Point(-6, 2), slope=-2)

# %%
line_d.slope
# Out:
# -2

# %%
line_d.equation()
# Out:
# 2⋅x + y + 10

# %%
plot(Rational(1,2)*x + 1, -2*x - 10, (x, -8, 2))

# %%
line_dp = Line(Point(0, 1), slope=Rational(1,2))

# %%
line_dp.slope
# Out:
# 1/2

# %%
line_d.is_perpendicular(line_dp)
# Out:
# True

# %%
line_d.contains(Point(-6, 2))
# Out:
# True

# %%
line_d.intersection(line_dp)
# Out:
# [Point2D(-22/5, -6/5)]

# %%
-22/5
# Out:
# -4.4

# %%
-6/5
# Out:
# -1.2

# %% [markdown]
# ### e) The perpendicular bisector of the line segment joining A(3,5) and B(7,17).

# %%
line_e = Line(Point(3,5), Point(7, 17))

# %%
line_e.equation()
# Out:
# -12⋅x + 4⋅y + 16

# %%
line_e_standard_form = (12 * x - 16) / 4;line_e_standard_form
# Out:
# 3⋅x - 4

# %%
line_e.slope
# Out:
# 3

# %%
segment_e = Segment(Point(3,5), Point(7,17))

# %%
midpointAB = segment_e.midpoint;midpointAB
# Out:
# Point2D(5, 11)

# %%
(17 - 5)/(7 - 3)
# Out:
# 3.0

# %%
(7 + 3)/2
# Out:
# 5.0

# %%
(17 + 5)/2
# Out:
# 11.0

# %%
perpendicular_bisector = Line(midpointAB, slope=Rational(-1, 3))

# %%
perpendicular_bisector.equation()
# Out:
# x       38
# ─ + y - ──
# 3       3

# %% [markdown]
# ## So our answer is y = -x/3 + 38/3

# %%
line_e.is_perpendicular(perpendicular_bisector)
# Out:
# True

# %%
plot(3*x - 4, Rational(-1,3)*x + Rational(38, 3))

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_1 = np.linspace(-10, 10, 100)
y_1 = 3 * x_1 + 1
y_2 = Rational(-1,3) * x_1 + Rational(38, 3)
fig, ax = plt.subplots()
ax.plot(x_1, y_1, label='slope = 3')
ax.plot(x_1, y_2, label='slope = -1/3')
plt.legend()
plt.show()

# %% [markdown]
# ### example 2
#
# Determine the point of intersection of y = 2x + 1 and the line perpendicular to y = -1/3 x + 4 passing through (0, -5)

# %%
line_a = Line(Point(0, 1), slope=2)

# %%
line_a.equation()
# Out:
# -2⋅x + y - 1

# %% [markdown]
# we need to find the 2nd line in the problem, a line that is perpendicuar to y = -1/3 x + 4 and passing through (0, -5)

# %%
line_b = Line(Point(0, -5), slope=3)

# %%
line_b.equation()
# Out:
# -3⋅x + y + 5

# %% [markdown]
# Now we need to find the point of intersection between these two lines.

# %%
line_a.intersection(line_b)
# Out:
# [Point2D(6, 13)]

# %%
line_a.contains(Point(6, 13))
# Out:
# True

# %%
line_b.contains(Point(6, 13))
# Out:
# True

# %%
Eq(3*x-5, 2*x + 1)
# Out:
# 3⋅x - 5 = 2⋅x + 1

# %%
solution_x = 2*x - 3*x + 5 + 1;solution_x
# Out:
# 6 - x

# %% [markdown]
# So x = 6

# %%
2*6 + 1 == 3*6 -5
# Out:
# True

# %%
3*6 - 5
# Out:
# 13

# %% [markdown]
# #### Therefore, our solution is point (6, 13)
