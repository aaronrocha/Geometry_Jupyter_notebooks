# %%
from sympy import *

# %%
init_printing()

# %%
x = symbols('x')

# %%
expr  = x**3 + x**2 - 12;expr
# Out:
#  3    2
# x  + x  - 12

# %%
factor(expr)
# Out:
#         ⎛ 2          ⎞
# (x - 2)⋅⎝x  + 3⋅x + 6⎠

# %%
plot(expr, (x, -5, 5))

# %%
solveset(Eq(expr, 0),x)
# Out:
# ⎧     3   √15⋅ⅈ    3   √15⋅ⅈ⎫
# ⎨2, - ─ - ─────, - ─ + ─────⎬
# ⎩     2     2      2     2  ⎭
