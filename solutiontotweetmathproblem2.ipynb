# %%
from sympy import *

# %%
init_printing()

# %%
x = symbols('x')

# %%
expr = 2/x + x/2 - 3/x - x/3;expr
# Out:
# x   1
# ─ - ─
# 6   x

# %%
solveset(Eq(expr, 0))
# Out:
# {-√6, √6}

# %%
N(sqrt(6))
# Out:
# 2.44948974278318

# %%
plot(expr, ylim=(-6, 6))
